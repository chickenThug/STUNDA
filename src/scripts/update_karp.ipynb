# %%
import requests
import json
from utils import get_all, add_entry, add_entries, delete_entry_by_id

# %%
json_data = get_all()
json_data
# Out:
# succesfull get
# {'total': 3781,
#  'hits': [{'id': '01HTT228BNK9VKCJ61XQQZZW2H',
#    'version': 1,
#    'last_modified': 1712419053.949,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d bin packing'},
#     'swe': {'lemma': '3d-lådpackning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT228MFCF199FDT6BSZQEQG',
#    'version': 1,
#    'last_modified': 1712419054.233924,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d collaborative mapping'},
#     'swe': {'lemma': '3d-samarbetskartläggning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT228Y4ZR77SEWY9Z71CGDZ',
#    'version': 1,
#    'last_modified': 1712419054.538581,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d data processing'},
#     'swe': {'lemma': '3d-databehandling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2297YHEQJN988EV30NCCY',
#    'version': 1,
#    'last_modified': 1712419054.851605,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d graphic'},
#     'swe': {'lemma': '3d-grafik'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT229H7Y7P11642F5AJRNCQ',
#    'version': 1,
#    'last_modified': 1712419055.148687,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d object classification'},
#     'swe': {'lemma': '3d-objektklassificering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT212E2BGCB2RXSQA1A2WVZ',
#    'version': 1,
#    'last_modified': 1712419015.113411,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d object detection'},
#     'swe': {'lemma': '3d-objektdetektering'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['3d-objektdetektion']}},
#   {'id': '01HTT22AC454J6K8X5WT8GC2QZ',
#    'version': 1,
#    'last_modified': 1712419056.009833,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d packaging'},
#     'swe': {'lemma': '3d-integrering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22ATA8QHQJNTKN4W3CN03',
#    'version': 1,
#    'last_modified': 1712419056.46373,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d point cloud'},
#     'swe': {'lemma': '3d-punktmoln'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22B2NHXV4E6JESZW60Q9Q',
#    'version': 1,
#    'last_modified': 1712419056.730386,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d pose estimation'},
#     'swe': {'lemma': '3d-positionsuppskattning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22BFVZ21W79XZY686JF71',
#    'version': 1,
#    'last_modified': 1712419057.156905,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d printing'},
#     'swe': {'lemma': 'friformsframställning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22BXZRTTE5FDV1TCPAQJZ',
#    'version': 1,
#    'last_modified': 1712419057.60474,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d reconstruction'},
#     'swe': {'lemma': '3d-rekonstruktion'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22C7P7Q3S3PQK9RQSNWKN',
#    'version': 1,
#    'last_modified': 1712419057.915049,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d shape recognition'},
#     'swe': {'lemma': '3d-formigenkänning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22CGW9RNM5HV0NPNDJ5MM',
#    'version': 1,
#    'last_modified': 1712419058.209893,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': '3d shape retrieval'},
#     'swe': {'lemma': '3d-formhämtning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22CY79QZJB7H03314FXW8',
#    'version': 1,
#    'last_modified': 1712419058.636319,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'ablation study'},
#     'swe': {'lemma': 'ablationsstudie'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22D7CM3VBFANQF91053BV',
#    'version': 1,
#    'last_modified': 1712419058.929613,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abnormality detection'},
#     'swe': {'lemma': 'onormal detektion'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22DGY3XNBJHNNZBXP6XYX',
#    'version': 1,
#    'last_modified': 1712419059.235868,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'absolute localization'},
#     'swe': {'lemma': 'absolut lokalisering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22DY4M5VQKRVZPT06W042',
#    'version': 1,
#    'last_modified': 1712419059.657495,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'absorption loss'},
#     'swe': {'lemma': 'absorptionsförlust'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22E6TH478JVP4GX4ZX8EP',
#    'version': 1,
#    'last_modified': 1712419059.935675,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abstract representation'},
#     'swe': {'lemma': 'abstrakt representation'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22EGZ23QP7ZNBWFPK4YRT',
#    'version': 1,
#    'last_modified': 1712419060.260968,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abstraction'},
#     'swe': {'lemma': 'abstraktion'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22ETGF4YJGN21888TY5HV',
#    'version': 1,
#    'last_modified': 1712419060.566426,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abstraction construction'},
#     'swe': {'lemma': 'abstraktionskonstruktion'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22F7H8EA86QKF9RS81ZM4',
#    'version': 1,
#    'last_modified': 1712419060.98265,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abstractive summarization'},
#     'swe': {'lemma': 'abstrakt sammanfattning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22FHMBKPHYT43W3VYANVC',
#    'version': 1,
#    'last_modified': 1712419061.307473,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'abstractive text summarization'},
#     'swe': {'lemma': 'abstrakt textsammanfattning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22FTKPJXDDRYJSXQZGY0P',
#    'version': 1,
#    'last_modified': 1712419061.592417,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'academic flying'},
#     'swe': {'lemma': 'akademiskt flygande'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22G45XJHZ0N816RSER7VQ',
#    'version': 1,
#    'last_modified': 1712419061.898451,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'academic integrity'},
#     'swe': {'lemma': 'akademisk integritet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22GDTB89YGZMTXX411DYN',
#    'version': 1,
#    'last_modified': 1712419062.207886,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'academic work'},
#     'swe': {'lemma': 'akademiskt arbete'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22GPNJD9BCK8W0B9NYA9P',
#    'version': 1,
#    'last_modified': 1712419062.490906,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accelerated life test'},
#     'swe': {'lemma': 'accelererat livslängdstest'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22GYN4E6RK9XQSSFVYQYG',
#    'version': 1,
#    'last_modified': 1712419062.751363,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accelerated signal processing software'},
#     'swe': {'lemma': 'accelererad signalbehandlingsmjukvara'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22H7D8Z1THECJMZ4J3X8D',
#    'version': 1,
#    'last_modified': 1712419063.026412,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accent'},
#     'swe': {'lemma': 'brytning'},
#     'pos': 'N',
#     'src': 'paired-keywords',
#     'synonyms': ['accent']}},
#   {'id': '01HTT22HM1AHQCVGMEFQKKZ0Q5',
#    'version': 1,
#    'last_modified': 1712419063.430529,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'access card'},
#     'swe': {'lemma': 'accesskort'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22HXVJQC05JZR32X239KX',
#    'version': 1,
#    'last_modified': 1712419063.7451,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'access control'},
#     'swe': {'lemma': 'åtkomstkontroll'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22J7D6YTE6JS7WYD45M5H',
#    'version': 1,
#    'last_modified': 1712419064.050645,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'access control system'},
#     'swe': {'lemma': 'passersystem'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22JH0WV4RWXTKYJHV8KX7',
#    'version': 1,
#    'last_modified': 1712419064.357661,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accessibility'},
#     'swe': {'lemma': 'tillgänglighet'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22JTW8XY9MNVZQ124869P',
#    'version': 1,
#    'last_modified': 1712419064.673449,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accident'},
#     'swe': {'lemma': 'olycka'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22K4FGWGNVY01T5Q8S1V6',
#    'version': 1,
#    'last_modified': 1712419064.980783,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'account takeover'},
#     'swe': {'lemma': 'kontoövertagelse'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22KDX2363NWH3N6GEXC8F',
#    'version': 1,
#    'last_modified': 1712419065.282122,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'accountability'},
#     'swe': {'lemma': 'ansvarighet'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22KQAFRPXTB6N8W59HZGC',
#    'version': 1,
#    'last_modified': 1712419065.583619,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'acoustic'},
#     'swe': {'lemma': 'musikakustik'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22KZNJ71FY76XS2MT8V56',
#    'version': 1,
#    'last_modified': 1712419065.850735,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'acoustic detection'},
#     'swe': {'lemma': 'akustisk detektering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22MBBNE838WPNKDN4KPXY',
#    'version': 1,
#    'last_modified': 1712419066.224772,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'acoustic signal processing'},
#     'swe': {'lemma': 'akustisk signalbehandling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22MQTX7VFNVAJCGNJHZER',
#    'version': 1,
#    'last_modified': 1712419066.624106,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'acquisition'},
#     'swe': {'lemma': 'anskaffning'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22N1KG0MK28TSPNGAN2CE',
#    'version': 1,
#    'last_modified': 1712419066.936148,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'action'},
#     'swe': {'lemma': 'aktivitet'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22NCSQH67MZV49XMWD60R',
#    'version': 1,
#    'last_modified': 1712419067.295369,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'action potential'},
#     'swe': {'lemma': 'nervimpuls'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22NM7VZ2ZD4VH296KMHSW',
#    'version': 1,
#    'last_modified': 1712419067.533044,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'action research'},
#     'swe': {'lemma': 'aktionsforskning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22NY02TB4G1WXNFTAW3KY',
#    'version': 1,
#    'last_modified': 1712419067.846522,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'activated carbon cloth'},
#     'swe': {'lemma': 'aktivt koltyg'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22P7Z19QF2BEHQ002AG03',
#    'version': 1,
#    'last_modified': 1712419068.164456,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'active electrode'},
#     'swe': {'lemma': 'aktiv elektrod'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22PHBKVWV9EHT4G8RWV5V',
#    'version': 1,
#    'last_modified': 1712419068.464879,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'active learning'},
#     'swe': {'lemma': 'aktiv inlärning'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['aktiv maskininlärning', 'aktivt lärande']}},
#   {'id': '01HTT22PTRSVPR36KQHBXK24ZG',
#    'version': 1,
#    'last_modified': 1712419068.766369,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'active listener'},
#     'swe': {'lemma': 'aktiv lyssnare'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22Q4YJNGNJM4Y9KJVWX1B',
#    'version': 1,
#    'last_modified': 1712419069.091949,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'active noise control'},
#     'swe': {'lemma': 'aktiv brusreducering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22QE1XAE61X3MXPG1TXQE',
#    'version': 1,
#    'last_modified': 1712419069.383214,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'active participation'},
#     'swe': {'lemma': 'aktiv medverkan'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22QQGN8Y2CAB6542FHB7N',
#    'version': 1,
#    'last_modified': 1712419069.68608,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'activity'},
#     'swe': {'lemma': 'aktivitet'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22R16EAXGJN2V7NB8QHX8',
#    'version': 1,
#    'last_modified': 1712419069.995857,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'activity tracking'},
#     'swe': {'lemma': 'aktivitetsspårning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22RFGQ39NKDF2HQ9K91N5',
#    'version': 1,
#    'last_modified': 1712419070.454062,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptation'},
#     'swe': {'lemma': 'anpassning'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22RQMCEW6TEQX3WFHDA9G',
#    'version': 1,
#    'last_modified': 1712419070.713191,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive control'},
#     'swe': {'lemma': 'adaptiv reglering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22S4TVWJTDH3XNKH30RS7',
#    'version': 1,
#    'last_modified': 1712419071.136166,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive counteraction'},
#     'swe': {'lemma': 'adaptiv motverkan'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22SEDZ5K2ZBHJVJ2EYQM2',
#    'version': 1,
#    'last_modified': 1712419071.442629,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive filter'},
#     'swe': {'lemma': 'adaptiv filtrering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22SQN2D04B76D4QDPKVEW',
#    'version': 1,
#    'last_modified': 1712419071.738658,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive learning'},
#     'swe': {'lemma': 'adaptivt lärande'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22T183RZHVX2KE634S2BS',
#    'version': 1,
#    'last_modified': 1712419072.0457,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive mesh refinement'},
#     'swe': {'lemma': 'adaptiv nätförfining'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22TAJ1BMX6JHJBEP8MR2X',
#    'version': 1,
#    'last_modified': 1712419072.343917,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive quantization'},
#     'swe': {'lemma': 'adaptiv kvantisering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22TMSRT0MDZE4YN6XZ2CX',
#    'version': 1,
#    'last_modified': 1712419072.671324,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive sampling'},
#     'swe': {'lemma': 'adaptiv sampling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22TYAWE41D4X1KHCPNX1W',
#    'version': 1,
#    'last_modified': 1712419072.975549,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adaptive sparsity'},
#     'swe': {'lemma': 'adaptiv gleshet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22V53RJ8BJF90XBVRPX5R',
#    'version': 1,
#    'last_modified': 1712419073.193054,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'address generation unit'},
#     'swe': {'lemma': 'adressgenereringsenhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22VE5PTFBPGXJRZW8PPSX',
#    'version': 1,
#    'last_modified': 1712419073.483717,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adjustment'},
#     'swe': {'lemma': 'trimning'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22VQS37P9STC5PJ77YMX6',
#    'version': 1,
#    'last_modified': 1712419073.790707,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'administration'},
#     'swe': {'lemma': 'administration'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22W1BRGXNR09WHTGZDP33',
#    'version': 1,
#    'last_modified': 1712419074.097033,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'admission control'},
#     'swe': {'lemma': 'antagningskontroll'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22WB7HHKFNCK6KE6W61R2',
#    'version': 1,
#    'last_modified': 1712419074.415021,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'admission data'},
#     'swe': {'lemma': 'antagningsdata'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22WQJJWB8507QN6AEP2GF',
#    'version': 1,
#    'last_modified': 1712419074.807551,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'adoption model'},
#     'swe': {'lemma': 'införandemodell'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22X152BQZH6MT771AP5S2',
#    'version': 1,
#    'last_modified': 1712419075.114475,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'advertisement'},
#     'swe': {'lemma': 'reklam'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22X7QJERDBW0HTSYD8MW9',
#    'version': 1,
#    'last_modified': 1712419075.324563,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'advertisement-based business model'},
#     'swe': {'lemma': 'annonsbaserad affärsmodell'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22XHNN8HTWVEEAKM3RZPC',
#    'version': 1,
#    'last_modified': 1712419075.643107,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'advertising'},
#     'swe': {'lemma': 'reklam'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22XVHB9666YE3ZERACZJB',
#    'version': 1,
#    'last_modified': 1712419075.958838,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'advertising industry'},
#     'swe': {'lemma': 'reklambransch'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22Y4RV5HHEH4CT6EWY3EE',
#    'version': 1,
#    'last_modified': 1712419076.254575,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aerial base station'},
#     'swe': {'lemma': 'antennbasstationer'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22YG5P0ZJS776RNREYNX9',
#    'version': 1,
#    'last_modified': 1712419076.623139,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aerial platform'},
#     'swe': {'lemma': 'flygplattform'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22YTWPZFRTKAFRK9GV9FD',
#    'version': 1,
#    'last_modified': 1712419076.96154,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aerial robot'},
#     'swe': {'lemma': 'flygrobot'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22Z4N0S1140T6D2V9PTXB',
#    'version': 1,
#    'last_modified': 1712419077.274888,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aerial swarm'},
#     'swe': {'lemma': 'drönarsvärm'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22ZEZQN6VBESZCQ48HPFD',
#    'version': 1,
#    'last_modified': 1712419077.605795,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aeronautics'},
#     'swe': {'lemma': 'aeronautik'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT22ZQM2VFNM4TZ62HCYTCH',
#    'version': 1,
#    'last_modified': 1712419077.882068,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aesthetic'},
#     'swe': {'lemma': 'estetik'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23016194GZ369HR8SCKFD',
#    'version': 1,
#    'last_modified': 1712419078.188042,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'affective computing'},
#     'swe': {'lemma': 'affektiv databehandling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT230AENS8CS9RPCHQWH786',
#    'version': 1,
#    'last_modified': 1712419078.483626,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'affective recognition'},
#     'swe': {'lemma': 'affektiv igenkänning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT230N4AB8Z3CZ6TA4M7XHW',
#    'version': 1,
#    'last_modified': 1712419078.826039,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'after study'},
#     'swe': {'lemma': 'efterstudie'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT230XZCDYAD94B4PS5Y295',
#    'version': 1,
#    'last_modified': 1712419079.109502,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'ageing process'},
#     'swe': {'lemma': 'åldringsprocess'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2317RZZ53H5Z96JXQQ32K',
#    'version': 1,
#    'last_modified': 1712419079.421418,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'agent'},
#     'swe': {'lemma': 'agent'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT231H9F96921QBY2CCV3JA',
#    'version': 1,
#    'last_modified': 1712419079.727063,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'agent-based model'},
#     'swe': {'lemma': 'agentbaserad modell'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT231TF2ZDSH8J1GGEHYBX5',
#    'version': 1,
#    'last_modified': 1712419080.020561,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'aggregation'},
#     'swe': {'lemma': 'aggregering'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2327XMBH080XGDJ22N3Q9',
#    'version': 1,
#    'last_modified': 1712419080.450541,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'air combat'},
#     'swe': {'lemma': 'luftstrid'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT232NJ1B39BP3NHTGQ8FGP',
#    'version': 1,
#    'last_modified': 1712419080.887586,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'air particle matter'},
#     'swe': {'lemma': 'luftpartiklar'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT232XN3FNFKXQ09M1ZVKM7',
#    'version': 1,
#    'last_modified': 1712419081.146426,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'air quality'},
#     'swe': {'lemma': 'luftkvalitet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2337GRD82NA2598WQ9DQ9',
#    'version': 1,
#    'last_modified': 1712419081.46203,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'air safety'},
#     'swe': {'lemma': 'flygsäkerhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT233K8QSTSFE4H64KNQ4SQ',
#    'version': 1,
#    'last_modified': 1712419081.838506,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'air temperature'},
#     'swe': {'lemma': 'lufttemperatur'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT233TBKH88GJ2AE3ZAW4Y7',
#    'version': 1,
#    'last_modified': 1712419082.065534,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'airplane'},
#     'swe': {'lemma': 'flygplan'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23446GCPXTSH8Z4H40H0V',
#    'version': 1,
#    'last_modified': 1712419082.379514,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'airport infrastructure technology'},
#     'swe': {'lemma': 'flygplatsinfrastrukturteknik'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT234DKH0T79RXH24HA2CJ4',
#    'version': 1,
#    'last_modified': 1712419082.682209,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'airport navigation'},
#     'swe': {'lemma': 'flygplatsnavigering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT234M844EABW31TN34JAVZ',
#    'version': 1,
#    'last_modified': 1712419082.893626,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'alerting system'},
#     'swe': {'lemma': 'varseblivning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT234XZF19MW65KTEXG75JT',
#    'version': 1,
#    'last_modified': 1712419083.204214,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algebraic topology'},
#     'swe': {'lemma': 'algebraisk topologi'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23579XYRKWT63HHPZ5CY7',
#    'version': 1,
#    'last_modified': 1712419083.503863,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algorithm'},
#     'swe': {'lemma': 'algoritm'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT235HFCZ03T5NXBF9EWD82',
#    'version': 1,
#    'last_modified': 1712419083.829279,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algorithm design'},
#     'swe': {'lemma': 'algoritmdesign'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT235TMZ9VZX93CX8FAVRJG',
#    'version': 1,
#    'last_modified': 1712419084.121715,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algorithm mapping'},
#     'swe': {'lemma': 'algoritmkartläggning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT236488MPX1ERFSZARGX4F',
#    'version': 1,
#    'last_modified': 1712419084.430212,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algorithm-friendly design'},
#     'swe': {'lemma': 'algoritmvänlig design'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT236AH30KERK27HCQVW7EF',
#    'version': 1,
#    'last_modified': 1712419084.631806,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'algorithm-hardware co-design'},
#     'swe': {'lemma': 'algoritm-hårdvarusamdesign'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT236PCT3XQ7SWDXXVZYVK6',
#    'version': 1,
#    'last_modified': 1712419085.009708,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'all-digital phase-locked-loops'},
#     'swe': {'lemma': 'helt-digital fas-låst-loop'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23716EWSG4KJFTRR3PRM2',
#    'version': 1,
#    'last_modified': 1712419085.355725,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'amateur radio'},
#     'swe': {'lemma': 'amatörradio'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2377J0R25C2SGZRQBH2V7',
#    'version': 1,
#    'last_modified': 1712419085.559391,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'amplifier'},
#     'swe': {'lemma': 'förstärkare'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT237GSE7NFSY2HPDAMEFJ0',
#    'version': 1,
#    'last_modified': 1712419085.854993,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'analysis'},
#     'swe': {'lemma': 'analys'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT237Q4D6GA4JB9N38FWCR8',
#    'version': 1,
#    'last_modified': 1712419086.057157,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'analytical model'},
#     'swe': {'lemma': 'analytisk modellering'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['analytisk modell', 'kompakt modell']}},
#   {'id': '01HTT2380B1XBTHQYAJMASAC3S',
#    'version': 1,
#    'last_modified': 1712419086.352543,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'analytical solution'},
#     'swe': {'lemma': 'analytisk lösning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2386NKQXVMA0XCX9Q070N',
#    'version': 1,
#    'last_modified': 1712419086.554543,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'android application'},
#     'swe': {'lemma': 'android-applikation'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT238DH6CB43MPA7XZCCRAK',
#    'version': 1,
#    'last_modified': 1712419086.774347,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'android application security'},
#     'swe': {'lemma': 'android-applikationssäkerhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT238KTQCBHPKH4GK2TKZFY',
#    'version': 1,
#    'last_modified': 1712419086.975368,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'angel investment'},
#     'swe': {'lemma': 'affärsängel'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT238XWYJJ2S1YVKC8AWPMK',
#    'version': 1,
#    'last_modified': 1712419087.297813,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'angular measurement'},
#     'swe': {'lemma': 'vinkelmätning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT2397X89MEZJM04NRYYMFW',
#    'version': 1,
#    'last_modified': 1712419087.618544,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'animation'},
#     'swe': {'lemma': 'animation'},
#     'pos': 'N',
#     'src': 'paired-keywords',
#     'synonyms': ['animering']}},
#   {'id': '01HTT239GX0FAG1EWXY8G76BHX',
#    'version': 1,
#    'last_modified': 1712419087.906652,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'animation synthesis'},
#     'swe': {'lemma': 'animations-syntes'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT239QDV5BN44DRS0DGZ13J',
#    'version': 1,
#    'last_modified': 1712419088.114618,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anomaly'},
#     'swe': {'lemma': 'anomali'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23A2Z333EVT64TCH9XQ08',
#    'version': 1,
#    'last_modified': 1712419088.485107,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anomaly correction'},
#     'swe': {'lemma': 'avvikelsekorrigering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23AAAA27P0J7JJZ99XH5D',
#    'version': 1,
#    'last_modified': 1712419088.719436,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anomaly detection'},
#     'swe': {'lemma': 'avvikelsedetektering'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['anomalidetektion',
#      'anomalidetektering',
#      'avvikelsedetektion',
#      'anomaliupptäckande',
#      'övervakningssystem']}},
#   {'id': '01HTT23AMAPNFAWS4T1WWNHVXB',
#    'version': 1,
#    'last_modified': 1712419089.039221,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anonymity'},
#     'swe': {'lemma': 'anonymitet'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23ATN9TXRY5D5ZDX6C394',
#    'version': 1,
#    'last_modified': 1712419089.243544,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anonymous authentication'},
#     'swe': {'lemma': 'anonym autentisering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23B3V13BZB7WS65Q2XNHH',
#    'version': 1,
#    'last_modified': 1712419089.53662,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna'},
#     'swe': {'lemma': 'antenn'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23BAQ913RQ0115PR27D9P',
#    'version': 1,
#    'last_modified': 1712419089.756119,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna alignment'},
#     'swe': {'lemma': 'antennorientering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23BMH2294F9AG9PVH2SNG',
#    'version': 1,
#    'last_modified': 1712419090.070079,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna array'},
#     'swe': {'lemma': 'antennuppsättning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23BXZ2TWEWRCBCXN2F40D',
#    'version': 1,
#    'last_modified': 1712419090.373107,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna design'},
#     'swe': {'lemma': 'antenndesign'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23C7ETQH9VSZZQ2H88QE5',
#    'version': 1,
#    'last_modified': 1712419090.675346,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna placement'},
#     'swe': {'lemma': 'antennplacering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23CGG7RZZEZA3WH2AQ6VR',
#    'version': 1,
#    'last_modified': 1712419090.965896,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna platform'},
#     'swe': {'lemma': 'antennplattform'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23CTPC9YH70NST4X52Q4P',
#    'version': 1,
#    'last_modified': 1712419091.291481,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna simulation'},
#     'swe': {'lemma': 'antennsimulering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23D45TF40MXD7H2J3S4GT',
#    'version': 1,
#    'last_modified': 1712419091.594805,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna system'},
#     'swe': {'lemma': 'antennsystem'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23DDTJPPFXZ7B886DDB28',
#    'version': 1,
#    'last_modified': 1712419091.903641,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna system response'},
#     'swe': {'lemma': 'antennsystemsvar'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23DQBMQVSC2EHM686H5RM',
#    'version': 1,
#    'last_modified': 1712419092.208501,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antenna tilt optimization'},
#     'swe': {'lemma': 'antennlutningsoptimering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23DY37ZRXK62CHVY6W2V3',
#    'version': 1,
#    'last_modified': 1712419092.424774,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'antibiotics prescription'},
#     'swe': {'lemma': 'antibiotikarecept'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23E7919B5M1XDK1SYBWSS',
#    'version': 1,
#    'last_modified': 1712419092.718627,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'anxiety'},
#     'swe': {'lemma': 'ångest'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23EH467DMGTRCXNMR07HV',
#    'version': 1,
#    'last_modified': 1712419093.03399,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'apache'},
#     'swe': {'lemma': 'apache'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23ET9Z9YAYAHBHJP7MTJC',
#    'version': 1,
#    'last_modified': 1712419093.327467,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application'},
#     'swe': {'lemma': 'utveckling'},
#     'pos': 'N',
#     'src': 'paired-keywords',
#     'synonyms': ['applikation']}},
#   {'id': '01HTT23F6ZACWEDB0Y4YWHX395',
#    'version': 1,
#    'last_modified': 1712419093.732206,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application form'},
#     'swe': {'lemma': 'ansökningsblankett'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23FHMVH1MTVS8FVJ5GPHF',
#    'version': 1,
#    'last_modified': 1712419094.073698,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application handiness'},
#     'swe': {'lemma': 'användarvänlighet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23FS10CVC8JWJ1KTVPC73',
#    'version': 1,
#    'last_modified': 1712419094.310136,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application isolation'},
#     'swe': {'lemma': 'applikationsisolering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23G137RATHVCAWDDTAZJZ',
#    'version': 1,
#    'last_modified': 1712419094.568853,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application security'},
#     'swe': {'lemma': 'applikationssäkerhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23GE48QC85YN4TJVDG90D',
#    'version': 1,
#    'last_modified': 1712419094.985602,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application specific instruction processor'},
#     'swe': {'lemma': 'applikationsspecifik instruktionsprocessor'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23GQBNZVDXGGWTBPG5QFS',
#    'version': 1,
#    'last_modified': 1712419095.280709,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'application type'},
#     'swe': {'lemma': 'applikationstyp'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23H15BGF7VC9BRASQM7T9',
#    'version': 1,
#    'last_modified': 1712419095.594997,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'applied-cryptography'},
#     'swe': {'lemma': 'tillämpad kryptografi'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23H9MS6MYF9XAV0G63869',
#    'version': 1,
#    'last_modified': 1712419095.865909,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'approximate computing'},
#     'swe': {'lemma': 'ungefärlig beräkning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23HHBG679W4E2D38QJ1ZJ',
#    'version': 1,
#    'last_modified': 1712419096.112507,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'approximation'},
#     'swe': {'lemma': 'approximation'},
#     'pos': 'N',
#     'src': 'paired-keywords',
#     'synonyms': ['uppskattning']}},
#   {'id': '01HTT23HT9EV6649GNCYT02AE9',
#    'version': 1,
#    'last_modified': 1712419096.399833,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'approximation algorithms'},
#     'swe': {'lemma': 'approximationsalgoritmer'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23J91N7P5W3QQ8NZ7ASFM',
#    'version': 1,
#    'last_modified': 1712419096.870696,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arc consistency'},
#     'swe': {'lemma': 'bågkonsekvens'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23JHKCF5ZB8CV2K5M1P41',
#    'version': 1,
#    'last_modified': 1712419097.145809,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arc incident energy'},
#     'swe': {'lemma': 'händelseenergi'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23JTNNN0V5C3FGB3QB6WN',
#    'version': 1,
#    'last_modified': 1712419097.434952,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arc squeezing'},
#     'swe': {'lemma': 'ljusbågssläckning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23K4E9SH4TNQZV280H0JT',
#    'version': 1,
#    'last_modified': 1712419097.748347,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'architectural pattern'},
#     'swe': {'lemma': 'arkitekturmönster'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23KDPFKE768K32WX992DN',
#    'version': 1,
#    'last_modified': 1712419098.044419,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'architecture'},
#     'swe': {'lemma': 'arkitektur'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23KQEQ45R4GPSSCJWX125',
#    'version': 1,
#    'last_modified': 1712419098.35609,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arctic geophysics'},
#     'swe': {'lemma': 'arktisk geofysik'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23M0Y1TGK7DDGKNW64DBG',
#    'version': 1,
#    'last_modified': 1712419098.659844,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'area exploration'},
#     'swe': {'lemma': 'områdesutforskning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23MAV0P19CEE6VAWPE3WT',
#    'version': 1,
#    'last_modified': 1712419098.977131,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arm'},
#     'swe': {'lemma': 'arm'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23MHQXKSER7C2YRBN7XS9',
#    'version': 1,
#    'last_modified': 1712419099.198129,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'arm micro-controller'},
#     'swe': {'lemma': 'arm-mikrokontroller'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23MTSWXFHPCP18NF9PEN5',
#    'version': 1,
#    'last_modified': 1712419099.48646,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'array antenna'},
#     'swe': {'lemma': 'gruppantenn'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23N7P4DXXP5BJGK213ZZT',
#    'version': 1,
#    'last_modified': 1712419099.899425,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'art'},
#     'swe': {'lemma': 'konst'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23NGWPDY5SG0MA1Q9QYRD',
#    'version': 1,
#    'last_modified': 1712419100.193604,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'article'},
#     'swe': {'lemma': 'artikel'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23NTNHNCZPN19QRNS1KZJ',
#    'version': 1,
#    'last_modified': 1712419100.507124,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'articulated vehicle'},
#     'swe': {'lemma': 'ledat fordon'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23P7T6DJT658VVFDJ0X9K',
#    'version': 1,
#    'last_modified': 1712419100.927652,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'artificial'},
#     'swe': {'lemma': 'artificiell'},
#     'pos': 'A',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23PH0P0HJD047HGP5S79E',
#    'version': 1,
#    'last_modified': 1712419101.221859,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'artificial agent'},
#     'swe': {'lemma': 'artificiell agent'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTT23PTXNQPEQ4ZY4ZEHF2H1',
#    'version': 1,
#    'last_modified': 1712419101.539035,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'artificial intelligence'},
#     'swe': {'lemma': 'artificiell intelligens'},
#     'pos': 'NP',
# ...
#     'swe': {'lemma': 'digital marknad'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE77JF6D1W4X69Z50G7G6P',
#    'version': 1,
#    'last_modified': 1712431799.892736,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital marketing'},
#     'swe': {'lemma': 'digital marknadsföring'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['digital marknadsförare']}},
#   {'id': '01HTTE77THEXRF9B12VPBV5B99',
#    'version': 1,
#    'last_modified': 1712431800.15097,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital maturity assessment'},
#     'swe': {'lemma': 'digitalt mognadstest'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE784668M81VCEJPYM1VZ5',
#    'version': 1,
#    'last_modified': 1712431800.460059,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital medium'},
#     'swe': {'lemma': 'digitalt medium'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE78DZRXN8NT3YG9B69JRJ',
#    'version': 1,
#    'last_modified': 1712431800.772947,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital migration'},
#     'swe': {'lemma': 'digital migration'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE78QYNTPSX5SZ7G1B6WET',
#    'version': 1,
#    'last_modified': 1712431801.091423,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital native'},
#     'swe': {'lemma': 'digital inföding'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7916W01Z98EP9G65A56J',
#    'version': 1,
#    'last_modified': 1712431801.390434,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital news'},
#     'swe': {'lemma': 'digital nyhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE79EK7K5E29AAEJ8FPVJR',
#    'version': 1,
#    'last_modified': 1712431801.816781,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital platform'},
#     'swe': {'lemma': 'digital plattform'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE79QVCNNXTKWB5170RRC6',
#    'version': 1,
#    'last_modified': 1712431802.112387,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital product design'},
#     'swe': {'lemma': 'digital produktdesign'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7A1186R89FM6FEQRMR4T',
#    'version': 1,
#    'last_modified': 1712431802.407379,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital security'},
#     'swe': {'lemma': 'datasäkerhet'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7AB7MPTM7WDRV6DNRWTM',
#    'version': 1,
#    'last_modified': 1712431802.733147,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital signal processor'},
#     'swe': {'lemma': 'digital signalprocessor'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7AM44AE2FY4EXAEJY7H7',
#    'version': 1,
#    'last_modified': 1712431803.01721,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital signature'},
#     'swe': {'lemma': 'digital signatur'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7AXMBK70PEZP17FZBJ3K',
#    'version': 1,
#    'last_modified': 1712431803.321186,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital track map'},
#     'swe': {'lemma': 'digital spårkarta'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7BAFW03PD59PQZ017Y0F',
#    'version': 1,
#    'last_modified': 1712431803.732571,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital transformation'},
#     'swe': {'lemma': 'klassifikation'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['digital transformation']}},
#   {'id': '01HTTE7BM8H6ES5M17YZKPRHDS',
#    'version': 1,
#    'last_modified': 1712431804.046056,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital twin'},
#     'swe': {'lemma': 'digital tvilling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7BV2ZYT8SF8GXJ0G41JH',
#    'version': 1,
#    'last_modified': 1712431804.263942,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital web environment'},
#     'swe': {'lemma': 'digital miljö'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7C4HMZ0XK254QDBNPA4G',
#    'version': 1,
#    'last_modified': 1712431804.566692,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digital wellbeing'},
#     'swe': {'lemma': 'digitalt välbefinnande'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7CDVHNKN2A2Z9T5JRCF9',
#    'version': 1,
#    'last_modified': 1712431804.863902,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'digitalization'},
#     'swe': {'lemma': 'digitalisering'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7CQ34RTW3PZ9N9WQW9HH',
#    'version': 1,
#    'last_modified': 1712431805.160474,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'dimensionality reduction'},
#     'swe': {'lemma': 'dimensionsreduktion'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['dimensionsreducering']}},
#   {'id': '01HTTE7D1C3QG2SFK6Y2TBZ8CB',
#    'version': 1,
#    'last_modified': 1712431805.489184,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'direct air-to-ground communication'},
#     'swe': {'lemma': 'direkt marknadskommunikation'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7DAQ94H3FXHHM3KS85VY',
#    'version': 1,
#    'last_modified': 1712431805.788053,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'direct memory access'},
#     'swe': {'lemma': 'direkt minnesåtkomst'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7DMAXC3TXBEAJ5E3VHZ6',
#    'version': 1,
#    'last_modified': 1712431806.095244,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'direct writing'},
#     'swe': {'lemma': '3d-utskrift'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7DY5HFS9TVE1T73J6YN4',
#    'version': 1,
#    'last_modified': 1712431806.41022,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'directed graphs'},
#     'swe': {'lemma': 'riktad grafer'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7EB2322HMGKD314M2SAC',
#    'version': 1,
#    'last_modified': 1712431806.823101,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'directional antenna'},
#     'swe': {'lemma': 'riktad antenn'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7EMHP6RKEWDNCJT6BPNN',
#    'version': 1,
#    'last_modified': 1712431807.126582,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'disability aid'},
#     'swe': {'lemma': 'hjälpmedel'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7F16FGTHWMVMG9WCQYJF',
#    'version': 1,
#    'last_modified': 1712431807.531191,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'disassembly'},
#     'swe': {'lemma': 'demontering'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7FAE59Z81CJJEGGMCBDC',
#    'version': 1,
#    'last_modified': 1712431807.828625,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'discrete event modelling'},
#     'swe': {'lemma': 'diskret modellering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7FJSSHF331Z5NTGVTXGZ',
#    'version': 1,
#    'last_modified': 1712431808.093928,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'discussion'},
#     'swe': {'lemma': 'diskussion'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7FTPDA7YEZ243QX7Q42G',
#    'version': 1,
#    'last_modified': 1712431808.347098,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'discussion environment'},
#     'swe': {'lemma': 'diskussionsmiljö'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7G4G30X0MTV4BAR0YA7N',
#    'version': 1,
#    'last_modified': 1712431808.661792,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'dispatch strategy'},
#     'swe': {'lemma': 'driftsstrategi'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7GE1R45XRQJRPHGTGZYN',
#    'version': 1,
#    'last_modified': 1712431808.967315,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'dispersion'},
#     'swe': {'lemma': 'dispersion'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7GQFEMDEECFPEGNX1JEY',
#    'version': 1,
#    'last_modified': 1712431809.269285,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'dispersion relation'},
#     'swe': {'lemma': 'dispersionsrelation'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7H1JZ33PH3JY4YM9NTX4',
#    'version': 1,
#    'last_modified': 1712431809.592574,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'displacement'},
#     'swe': {'lemma': 'förskjutning'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7HC7KTVF3DKT7Z0R8NR6',
#    'version': 1,
#    'last_modified': 1712431809.933613,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'dispute tree'},
#     'swe': {'lemma': 'tvisteträd'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7HQXJMCVPHEQYZY15YY9',
#    'version': 1,
#    'last_modified': 1712431810.306766,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'disruption'},
#     'swe': {'lemma': 'störning'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7J359MZT63Q3PZW0BA33',
#    'version': 1,
#    'last_modified': 1712431810.667581,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distance'},
#     'swe': {'lemma': 'avstånd'},
#     'pos': 'N',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7JAKFCE0KT02QRGGNNT4',
#    'version': 1,
#    'last_modified': 1712431810.905023,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distance based'},
#     'swe': {'lemma': 'avståndsbaserad'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7JJTK9FK88NX4CK1T6K8',
#    'version': 1,
#    'last_modified': 1712431811.167477,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distance-based model'},
#     'swe': {'lemma': 'distansbaserad modell'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7JSHV88YY29MQJGSRJT5',
#    'version': 1,
#    'last_modified': 1712431811.382499,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed computing'},
#     'swe': {'lemma': 'distribuerad databehandling'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7K2DR6G10EM2H05KZZJG',
#    'version': 1,
#    'last_modified': 1712431811.666549,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed database'},
#     'swe': {'lemma': 'fond'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7KB90F0WMHTZPKZ7S6GN',
#    'version': 1,
#    'last_modified': 1712431811.951228,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed estimation'},
#     'swe': {'lemma': 'distribuerad uppskattning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7KK0VR74B6QJRGS5H2HX',
#    'version': 1,
#    'last_modified': 1712431812.198623,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed file system'},
#     'swe': {'lemma': 'distribuerat filsystem'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7KTHTWPX55XFF58H97FQ',
#    'version': 1,
#    'last_modified': 1712431812.438855,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed generation'},
#     'swe': {'lemma': 'distribuerad produktion'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7M8G9MBH2CA3HSP2NFDW',
#    'version': 1,
#    'last_modified': 1712431812.886107,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed ledger'},
#     'swe': {'lemma': 'distribuerad huvudbok'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7MHGDQAAZWYSQR0VAXNB',
#    'version': 1,
#    'last_modified': 1712431813.173649,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed ledger technology'},
#     'swe': {'lemma': 'distribuerad huvudboksteknik'},
#     'pos': 'NP',
#     'src': 'paired-keywords',
#     'synonyms': ['blockkedja']}},
#   {'id': '01HTTE7MTHX0AC1D32GS0JVJAT',
#    'version': 1,
#    'last_modified': 1712431813.462939,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed machine learning'},
#     'swe': {'lemma': 'distribuerad maskininlärning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7N7WKBRWYTKNN92FX1NS',
#    'version': 1,
#    'last_modified': 1712431813.890182,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed pair programming'},
#     'swe': {'lemma': 'distribuerad parprogrammering'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7NHHZ7S8HJH089G823RF',
#    'version': 1,
#    'last_modified': 1712431814.19948,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed parameter system'},
#     'swe': {'lemma': 'distribuerat parametersystem'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7NTS3T1J6TJZWWV1NZYY',
#    'version': 1,
#    'last_modified': 1712431814.494982,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed power generation'},
#     'swe': {'lemma': 'distribuerad kraftproduktion'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7P4Y73KENY6Q1JN5S7M5',
#    'version': 1,
#    'last_modified': 1712431814.819495,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed scheduling'},
#     'swe': {'lemma': 'distribuerad schemaläggning'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   {'id': '01HTTE7PE3DDWMYP7XW3W5TD1V',
#    'version': 1,
#    'last_modified': 1712431815.113173,
#    'last_modified_by': 'rinoh-gafom@eduid.se',
#    'resource': 'stunda',
#    'entry': {'eng': {'lemma': 'distributed sensor network'},
#     'swe': {'lemma': 'distribuerat sensornätverk'},
#     'pos': 'NP',
#     'src': 'paired-keywords'}},
#   ...],
#  'distribution': {'stunda': 3781}}

# %%
json_string = json.dumps(json_data, indent=4)  # Add indentation for readability

# Specify the file path where you want to save the JSON data
file_path = "karp_og_data.json"

# Write JSON data to file
with open("../../public_data/" + file_path, 'w') as file:
    file.write(json_string)

# %%
entries = json_data["hits"]
print(len(entries))

authorization = json.load(open('../../data/secrets.json')).get("jwt_token", "")

deleted = 0
print(authorization)
for index, entry in enumerate(entries):
    id = entry["id"]
    res = delete_entry_by_id(id, authorization)
    
    deleted = deleted + 1 if res else deleted 
    if index % 500 == 0:
        print(f"processed {index+1} requests of which {deleted} were sucessfull")
# Out:
# 23
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....RJIaIGMzw4Kn7vjz0JUzxbF9O5DLtBDqDEmY3CmJGF3sL5W4UzzchIYFV2A6CW-ns6dYkiLabJh1zizeIwraYVC6Zx1eIh8xGaDsVP40QUniEA9BiALI0Jn0dDVZFqoYCsuwAxe0Y-YzOKzHHjOc8YVocF4va86brmaQx5MlBrbyxT0PNUAFNX0URu7ZHIsR9pvrftTqFKdeIQOrhAKt1AmitDZ2fURTJNaixR0PzhU6vE4EGwfUeS4SLY75xqxSJSujD6-qKLR9bLPX0D4Jy5KQHE1frB5GmJa4LA2iXFO8YXvhM_SsJ6CewB1pXn7VN092iGSLBwV4EK13d6PX6w
# processed 1 requests of which 1 were sucessfull

# %%
import pandas as pd
path = "../../"
file = "ready_for_karp.csv"

df = pd.read_csv(path+file)

# %%
df.status.value_counts()
# Out:
# status
# automatically verified                         4357
# swedish misspelt                               1863
# both misspelt                                  1785
# english misspelt                                856
# no processing rule for swedish POS sequence     508
# no pos found                                    473
# suspected särskriving                           322
# invalid characters in lemma                     206
# could not lemmatize swedish adjective           185
# too many possible pos tags: A N                   7
# too many possible pos tags: N V                   7
# no translation                                    1
# too many possible pos tags: Ab A                  1
# Name: count, dtype: int64

# %%
import pandas as pd

path = "../../"
file = "ready_for_karp2.csv"

df2 = pd.read_csv(path+file)

df2 = df2[df2["status"] == "automatically verified"].copy().drop_duplicates()


df2 = df2.groupby(["English lemma", "POS", "status"])["Swedish lemma"].agg(lambda x: ';'.join(x)).reset_index()

df2
# Out:
#              English lemma POS                  status      Swedish lemma
# 0                2d method  NP  automatically verified           2d-metod
# 1             3d modelling  NP  automatically verified     3d-modellering
# 2                  abandon   V  automatically verified           övergiva
# 3                  ability   N  automatically verified            förmåga
# 4                  absence   N  automatically verified           frånvaro
# ...                    ...  ..                     ...                ...
# 2732             worldwide   A  automatically verified             global
# 2733  worldwide world-wide  NP  automatically verified  världsomspännande
# 2734                 write   V  automatically verified             skriva
# 2735                writer   N  automatically verified         författare
# 2736                 yield   N  automatically verified             utbyte
#
# [2737 rows x 4 columns]

# %%
import pandas as pd

path = "../../"
file = "ready_for_karp_v2.csv"

df = pd.read_csv(path+file)

df = df[df["status"] == "automatically verified"].copy().drop_duplicates()


df = df.groupby(["English lemma", "POS", "status"])["Swedish lemma"].agg(lambda x: ';'.join(x)).reset_index()

df[df["Swedish lemma"].str.contains(";")]
# Out:
#                English lemma POS                  status  \
# 5        3d object detection  NP  automatically verified
# 27                    accent   N  automatically verified
# 44           active learning  NP  automatically verified
# 101         analytical model  NP  automatically verified
# 107                animation   N  automatically verified
# ...                      ...  ..                     ...
# 3684       visual impairment  NP  automatically verified
# 3746               wellbeing   N  automatically verified
# 3747                    wind   N  automatically verified
# 3757  wireless communication  NP  automatically verified
# 3773                workshop   N  automatically verified
#
#                                           Swedish lemma
# 5               3d-objektdetektering;3d-objektdetektion
# 27                                      brytning;accent
# 44    aktiv inlärning;aktiv maskininlärning;aktivt l...
# 101   analytisk modellering;analytisk modell;kompakt...
# 107                                 animation;animering
# ...                                                 ...
# 3684                           synnedsättning;synskadad
# 3746                            välmående;välbefinnande
# 3747                                     vindkraft;vind
# 3757      trådlös kommunikation;artificiell intelligens
# 3773                                 workshops;verkstad
#
# [279 rows x 4 columns]

# %%
df2 = df2[~df2["English lemma"].isin(df["English lemma"])].copy()

# %%
df[df["Swedish lemma"].str.contains(";")]
# Out:
#                English lemma POS                  status  \
# 5        3d object detection  NP  automatically verified
# 27                    accent   N  automatically verified
# 44           active learning  NP  automatically verified
# 101         analytical model  NP  automatically verified
# 107                animation   N  automatically verified
# ...                      ...  ..                     ...
# 3684       visual impairment  NP  automatically verified
# 3746               wellbeing   N  automatically verified
# 3747                    wind   N  automatically verified
# 3757  wireless communication  NP  automatically verified
# 3773                workshop   N  automatically verified
#
#                                           Swedish lemma
# 5               3d-objektdetektering;3d-objektdetektion
# 27                                      brytning;accent
# 44    aktiv inlärning;aktiv maskininlärning;aktivt l...
# 101   analytisk modellering;analytisk modell;kompakt...
# 107                                 animation;animering
# ...                                                 ...
# 3684                           synnedsättning;synskadad
# 3746                            välmående;välbefinnande
# 3747                                     vindkraft;vind
# 3757      trådlös kommunikation;artificiell intelligens
# 3773                                 workshops;verkstad
#
# [279 rows x 4 columns]

# %%
list_of_dicts = df2.to_dict(orient='records')

new_list = []

for item in list_of_dicts:

    swedish_translations = item["Swedish lemma"].split(";")
    new_item = {
        "eng": {
            "lemma": item["English lemma"]
        },
        "swe": {
            "lemma": swedish_translations[0]
        },
        "src": "paired-keywords",
        "pos": item["POS"]
    }
    if len(swedish_translations) > 1:
        new_item["synonyms"] = swedish_translations[1:]
    new_list.append(new_item)

print(len(new_list))
# Out:
# 2158

# %%
added = 0
authorization = json.load(open('../../data/secrets.json')).get("jwt_token", "")
for j, entry in enumerate(new_list[694:]):
    
    res = add_entry(authorization, entry)
    
    if res is not None:
        added += 1

    if j % 300 == 0:
        print(added, j+1)
# Out:
# 1 1
# 301 301
# 601 601
# 901 901
# 1201 1201

# %%
res = add_entries(authorization, entries)
true_count = res.count(True)
print("Number of sucessfull requests:", true_count)
print("Number of requests:", len(res))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 res = add_entries(authorization, entries)
#       2 true_count = res.count(True)
#       3 print("Number of sucessfull requests:", true_count)
#
# File ~/Documents/school/STUNDA/src/scripts/utils.py:102, in add_entries(authorization, entries, verbose)
#     100 results = []
#     101 for entry in entries:
# --> 102     results.append(add_entry(authorization, entry, verbose))
#     103 return results
#
# File ~/Documents/school/STUNDA/src/scripts/utils.py:87, in add_entry(authorization, entry, verbose)
#      77 headers = {
#      78 'Authorization': "Bearer " + authorization,
#      79 'Content-Type': 'application/json',
#      80 }
#      82 data = {
#      83     "entry" : entry,
#      84     "message": ""
#      85 }
# ---> 87 response = requests.put(url, headers=headers, json=data)
#      89 if response.status_code == 201:
#      90     if verbose:
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/requests/api.py:130, in put(url, data, **kwargs)
#     118 def put(url, data=None, **kwargs):
#     119     r"""Sends a PUT request.
#     120
#     121     :param url: URL for the new :class:`Request` object.
#    (...)
#     127     :rtype: requests.Response
#     128     """
# --> 130     return request("put", url, data=data, **kwargs)
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/python11/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/python11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/miniconda3/envs/python11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/python11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/python11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/envs/python11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/python11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
